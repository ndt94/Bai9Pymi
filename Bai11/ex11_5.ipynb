# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    '/home/jessenguyen/pyfml/exercises/dientich.csv',
    index_col=0,
    sep=';',
    skiprows=2,
    skipfooter=4,
    engine='python'
)

# %%
df1 = df.drop(df.index[0])

# %%
df1
# Out:
#                                          2011     2012     2013     2014  \
#
# Đồng bằng sông Hồng                   21068.1  21050.9  21059.3  21060.0
# Hà Nội                                 3328.9   3323.6   3324.3   3324.5
# Vĩnh Phúc                              1236.5   1236.5   1238.6   1237.5
# Bắc Ninh                                822.7    822.7    822.7    822.7
# Quảng Ninh                             6102.4   6102.3   6102.4   6102.3
# Hải Dương                              1656.0   1656.0   1656.0   1656.0
# Hải Phòng                              1523.4   1523.9   1527.4   1527.4
# Hưng Yên                                926.0    926.0    926.0    926.0
# Thái Bình                              1570.0   1570.0   1570.5   1570.8
# Hà Nam                                  860.5    860.5    860.5    862.0
# Nam Định                               1651.4   1652.6   1652.8   1653.2
# Ninh Bình                              1390.3   1376.7   1378.1   1377.6
# ...

# %%
df1 = df1.astype(float)

# %%
result= df1['2015'].sort_values().tail(10);result
# Out:
#
# Đắk Lắk                                 13125.4
# Sơn La                                  14174.4
# Gia Lai                                 15536.9
# Nghệ An                                 16490.0
# Đồng bằng sông Hồng                     21060.0
# Đông Nam Bộ                             23590.7
# Đồng bằng sông Cửu Long                 40576.0
# Tây Nguyên                              54641.0
# Trung du và miền núi phía Bắc           95266.8
# Bắc Trung Bộ và Duyên hải miền Trung    95832.4
# Name: 2015, dtype: float64

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
ax = result.plot(kind='bar',title='Diện tích 10 tỉnh lớn nhất Việt Nam năm 2015')
ax.set_ylabel('Km2')
# Out:
# Text(0,0.5,'Km2')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
numbers = np.array(np.random.randint(low=1, high=100, size=1000))

# %%
Days = pd.to_datetime([i for i in range(1000)], unit='D',
                   origin=pd.Timestamp('2010-02-09'))

# %%
Days
# Out:
# DatetimeIndex(['2010-02-09', '2010-02-10', '2010-02-11', '2010-02-12',
#                '2010-02-13', '2010-02-14', '2010-02-15', '2010-02-16',
#                '2010-02-17', '2010-02-18',
#                ...
#                '2012-10-26', '2012-10-27', '2012-10-28', '2012-10-29',
#                '2012-10-30', '2012-10-31', '2012-11-01', '2012-11-02',
#                '2012-11-03', '2012-11-04'],
#               dtype='datetime64[ns]', length=1000, freq=None)

# %%
result = pd.Series(lst, Days); result
# Out:
# 2010-02-09    81
# 2010-02-10    17
# 2010-02-11    14
# 2010-02-12    13
# 2010-02-13    96
# 2010-02-14    16
# 2010-02-15    99
# 2010-02-16    55
# 2010-02-17    71
# 2010-02-18    15
# 2010-02-19    97
# 2010-02-20    75
# 2010-02-21    16
# 2010-02-22    80
# 2010-02-23    87
# 2010-02-24    16
# 2010-02-25    90
# 2010-02-26    56
# 2010-02-27    57
# 2010-02-28    28
# 2010-03-01    31
# 2010-03-02    70
# 2010-03-03    87
# 2010-03-04    24
# 2010-03-05    45
# 2010-03-06    73
# 2010-03-07    39
# 2010-03-08    99
# 2010-03-09    28
# 2010-03-10    17
#               ..
# 2012-10-06    98
# 2012-10-07    40
# 2012-10-08    64
# 2012-10-09    30
# 2012-10-10    77
# 2012-10-11    13
# 2012-10-12    58
# 2012-10-13    94
# 2012-10-14    26
# 2012-10-15    71
# 2012-10-16    25
# 2012-10-17    33
# 2012-10-18    19
# 2012-10-19    13
# 2012-10-20    88
# 2012-10-21    16
# 2012-10-22    60
# 2012-10-23    72
# 2012-10-24    25
# 2012-10-25    63
# 2012-10-26    34
# ...

# %%
result.cumsum()
# Out:
# 2010-02-09       81
# 2010-02-10       98
# 2010-02-11      112
# 2010-02-12      125
# 2010-02-13      221
# 2010-02-14      237
# 2010-02-15      336
# 2010-02-16      391
# 2010-02-17      462
# 2010-02-18      477
# 2010-02-19      574
# 2010-02-20      649
# 2010-02-21      665
# 2010-02-22      745
# 2010-02-23      832
# 2010-02-24      848
# 2010-02-25      938
# 2010-02-26      994
# 2010-02-27     1051
# 2010-02-28     1079
# 2010-03-01     1110
# 2010-03-02     1180
# 2010-03-03     1267
# 2010-03-04     1291
# 2010-03-05     1336
# 2010-03-06     1409
# 2010-03-07     1448
# 2010-03-08     1547
# 2010-03-09     1575
# 2010-03-10     1592
#               ...
# 2012-10-06    49913
# 2012-10-07    49953
# 2012-10-08    50017
# 2012-10-09    50047
# 2012-10-10    50124
# 2012-10-11    50137
# 2012-10-12    50195
# 2012-10-13    50289
# 2012-10-14    50315
# 2012-10-15    50386
# 2012-10-16    50411
# 2012-10-17    50444
# 2012-10-18    50463
# 2012-10-19    50476
# ...

# %%
plt.plot(result)

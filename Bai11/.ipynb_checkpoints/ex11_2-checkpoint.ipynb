# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi)
sin_ = np.sin(x)
cos_ = np.cos(x)
tan_ = np.tan(x)
#plt.plot(x, sin_, x, cos_, x, tan_)
plt.plot(x, sin_)
plt.plot(x, cos_)
plt.plot(x, tan_)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    '/home/jessenguyen/pyfml/exercises/localbtcVND.csv',
    names = ['Time','VND','_'],
    dtype={'VND': 'str'}
)

# %%
df['Time'] = pd.to_datetime(df['Time'].astype(int), unit='s')

# %%
df
# Out:
#                     Time                     VND         _
# 0    2014-02-14 01:59:41   16102220.610000000000  0.701800
# 1    2014-03-25 11:43:25   13454060.690000000000  0.185817
# 2    2014-03-28 14:52:59   11833327.730000000000  0.198423
# 3    2014-03-31 08:54:47   11549259.330000000000  0.200000
# 4    2014-05-16 16:04:07   11368863.040000000000  0.215700
# 5    2014-06-02 03:09:44   15987724.200000000000  0.155600
# 6    2014-06-21 09:33:40   10666465.070000000000  0.003600
# 7    2014-08-07 18:13:01   14951439.910000000000  1.184100
# 8    2014-08-12 14:39:13   10215147.030000000000  0.021900
# 9    2014-08-12 18:48:36   10299824.180000000000  0.027300
# 10   2014-08-14 11:42:12   12531328.320000000000  0.039900
# 11   2014-08-19 14:00:01   11661807.580000000000  0.034300
# 12   2014-08-24 05:49:32   12747130.220000000000  0.166100
# 13   2014-10-01 05:25:32    9518117.000000000000  0.030000
# 14   2014-10-10 11:54:47    9377344.340000000000  0.133300
# ...

# %%
df[df['VND']==df['VND'].max()]
# Out:
#                     Time                    VND        _
# 1186 2017-09-07 07:50:28  99811763.250000000000  0.28173

# %%
# Alternative way
df[df.VND==df.VND.max()]
# Out:
#                     Time                    VND        _
# 1186 2017-09-07 07:50:28  99811763.250000000000  0.28173
